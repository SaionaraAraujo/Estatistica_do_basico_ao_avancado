# %% [markdown]
# <a href="https://colab.research.google.com/github/SaionaraAraujo/Estatistica_Renata/blob/main/Aula_1__Estat%C3%ADsitica_Descritiva.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Preparar ambiente

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/drive/MyDrive/mkt_data.csv')

# %% [markdown]
# #Conhecendo os dados

# %%
df.head(100)
# Out:
#     Unnamed: 0   Income  Kidhome  Teenhome  Recency  MntWines  MntFruits  \
# 0            0  58138.0        0         0       58       635         88
# 1            1  46344.0        1         1       38        11          1
# 2            2  71613.0        0         0       26       426         49
# 3            3  26646.0        1         0       26        11          4
# 4            4  58293.0        1         0       94       173         43
# ..         ...      ...      ...       ...      ...       ...        ...
# 95          95  87195.0        0         0       35       217         76
# 96          96  24594.0        1         0       94         1          3
# 97          97  49096.0        1         1       15       144          1
# 98          98  52413.0        0         2       56       295        106
# 99          99  38557.0        1         0       17        76          3
#
#     MntMeatProducts  MntFishProducts  MntSweetProducts  ...  \
# ...

# %% [markdown]
# #Quantos dados temos (linhas e colunas)

# %%
df.shape
# Out:
# (2205, 44)

# %% [markdown]
# #Quais as colunas numéricas

# %%
df.dtypes
# Out:
# Unnamed: 0                int64
# Income                  float64
# Kidhome                   int64
# Teenhome                  int64
# Recency                   int64
# MntWines                  int64
# MntFruits                 int64
# MntMeatProducts           int64
# MntFishProducts           int64
# MntSweetProducts          int64
# MntGoldProds              int64
# NumDealsPurchases         int64
# NumWebPurchases           int64
# NumCatalogPurchases       int64
# NumStorePurchases         int64
# NumWebVisitsMonth         int64
# AcceptedCmp3              int64
# AcceptedCmp4              int64
# AcceptedCmp5              int64
# AcceptedCmp1              int64
# AcceptedCmp2              int64
# Complain                  int64
# Z_CostContact             int64
# Z_Revenue                 int64
# Response                  int64
# Age                       int64
# Customer_Days             int64
# marital_Divorced        float64
# marital_Married         float64
# ...

# %% [markdown]
# #Valores Duplicados

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2200    False
# 2201    False
# 2202    False
# 2203    False
# 2204    False
# Length: 2205, dtype: bool

# %%
df.duplicated().value_counts()
# Out:
# False    2205
# dtype: int64

# %% [markdown]
# Não há valores repetidos.

# %% [markdown]
# #Valores ausentes

# %%
(df.isnull().sum()/df.shape[0]).sort_values(ascending = False)*100
# Out:
# education_Basic         97.551020
# marital_Widow           96.553288
# education_2n Cycle      91.020408
# marital_Divorced        89.569161
# education_Master        83.492063
# education_PhD           78.412698
# marital_Single          78.367347
# marital_Together        74.240363
# marital_Married         61.269841
# education_Graduation    49.523810
# Response                 0.000000
# Age                      0.000000
# Customer_Days            0.000000
# Unnamed: 0               0.000000
# Income                   0.000000
# MntTotal                 0.000000
# MntRegularProds          0.000000
# AcceptedCmpOverall       0.000000
# marital_status           0.000000
# education_level          0.000000
# kids                     0.000000
# Z_Revenue                0.000000
# Z_CostContact            0.000000
# Complain                 0.000000
# MntGoldProds             0.000000
# Kidhome                  0.000000
# Teenhome                 0.000000
# ...

# %% [markdown]
# Podemos ver que a 3 colunas tem muitos dados ausentes, mais de 90%. Nestes casos, podemos perceber que, por exemplo, 96% das pessoas cadastradas não são viúvas, já que a coluna que indica essa condição está vazia. Podemos ver também, que 97% dos registros não tem educação básica, o que não quer dizer que tenha níveis mais baixos que este, mas sim que não é exatamente o nível educacional desta parcela de clientes.
#
# education_Basic  - 97.551020%
#
# marital_Widow  - 96.553288%
#
# education_2n Cycle - 91.020408%
#
# marital_Divorced  - 89.569161%
#
# education_Master  - 83.492063%
#
# education_PhD - 78.412698%
#
# marital_Single - 78.367347%
#
# marital_Together - 74.240363%
#
# marital_Married - 61.269841%
#
# education_Graduation - 49.523810%

# %% [markdown]
# #Variáveis estatísticas das colunas numéricas

# %%
df.describe()
# Out:
#         Unnamed: 0         Income      Kidhome     Teenhome      Recency  \
# count  2205.000000    2205.000000  2205.000000  2205.000000  2205.000000
# mean   1102.000000   51622.094785     0.442177     0.506576    49.009070
# std     636.672993   20713.063826     0.537132     0.544380    28.932111
# min       0.000000    1730.000000     0.000000     0.000000     0.000000
# 25%     551.000000   35196.000000     0.000000     0.000000    24.000000
# 50%    1102.000000   51287.000000     0.000000     0.000000    49.000000
# 75%    1653.000000   68281.000000     1.000000     1.000000    74.000000
# max    2204.000000  113734.000000     2.000000     2.000000    99.000000
#
#           MntWines    MntFruits  MntMeatProducts  MntFishProducts  \
# count  2205.000000  2205.000000      2205.000000      2205.000000
# mean    306.164626    26.403175       165.312018        37.756463
# std     337.493839    39.784484       217.784507        54.824635
# ...

# %% [markdown]
# #Perfil do Cliente

# %% [markdown]
# Maior salário:

# %%
max(df['Income'])
# Out:
# 113734.0

# %% [markdown]
# Distribuição de salários

# %%
#Plotar histograma com valores relativos da temperatura média

fig, ax = plt.subplots()

#Definir a coluna a ser plotada, a origem do dado e a quantidade de barras
ax.hist('Income', data = df, bins = 10, density=True)

#títulos
ax.set_title("Histograma Salários")
ax.set_xlabel("Salários")
ax.set_ylabel("Ocorrências")

plt.tight_layout()

# %% [markdown]
# Agora vamos analisar o nível escolar:

# %%
df['education_level'].value_counts()
# Out:
# Graduation    1113
# PhD            476
# Master         364
# 2n Cycle       198
# Basic           54
# Name: education_level, dtype: int64

# %%
df['education_level'].value_counts().plot(kind='bar');

# %% [markdown]
# Agora vamos analisar os clientes por estado civil:

# %%
df['marital_status'].value_counts().plot(kind = 'bar')

# %% [markdown]
# #Matriz de correlação

# %%
df.corr()
# Out:
#                       Unnamed: 0    Income   Kidhome  Teenhome   Recency  \
# Unnamed: 0              1.000000 -0.002086 -0.019185  0.037771 -0.001757
# Income                 -0.002086  1.000000 -0.531699  0.042483  0.006716
# Kidhome                -0.019185 -0.531699  1.000000 -0.040207  0.011829
# Teenhome                0.037771  0.042483 -0.040207  1.000000  0.013881
# Recency                -0.001757  0.006716  0.011829  0.013881  1.000000
# MntWines                0.000725  0.730495 -0.499288  0.002783  0.016470
# MntFruits               0.025828  0.537920 -0.374388 -0.176925 -0.004909
# MntMeatProducts        -0.000530  0.702500 -0.445665 -0.267177  0.026138
# MntFishProducts         0.006233  0.551758 -0.389895 -0.206371  0.001177
# MntSweetProducts       -0.004239  0.555601 -0.379101 -0.164246  0.025535
# MntGoldProds            0.013152  0.417653 -0.356550 -0.019619  0.018558
# NumDealsPurchases       0.012935 -0.132427  0.226434  0.394341  0.000479
# ...

# %% [markdown]
# ##Correlação estudo x salário

# %% [markdown]
# Será que há relação entre o salário e a escolaridade dos clientes? Vamos plotar um gráfico de dispersão entre as duas variáveis, baseando em nos dois níveis mais alto e baixo e analisar:

# %%
#df['Income'].corr(df['education_level'])

# %%
df['Income'].corr(df['kids'])
# Out:
# -0.3503133281513374
